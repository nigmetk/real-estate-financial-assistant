# %%
#import sys
#!{sys.executable} -m pip uninstall -y scikit-learn numpy scipy

# %%
#import sys
#print(sys.executable)

# %%
#import sys
#!{sys.executable} -m pip install numpy==1.26.4 scikit-learn==1.2.2 scipy==1.10.1 joblib

# %%
import sklearn, numpy, scipy

print(sklearn.__version__)
print(numpy.__version__)
print(scipy.__version__)
# Out:
# 1.2.2
# 1.26.4
# 1.10.1

# %%
import joblib

reg_model = joblib.load(r"C:\Users\nimte\OneDrive\Desktop\real-estate-financial-assistant\models\local\regression\random_forest_model.pkl")

print("Regression model loaded 🚀")
# Out:
# Regression model loaded 🚀

# %%
sample = [1200, 3, 2, 2005, 300000]  # örnek

# %%
sample = [0, 0, 0, 0, 0]

# %%
print(reg_model.predict([sample]))

# %%
import joblib

class_model = joblib.load(r"C:\Users\nimte\OneDrive\Desktop\real-estate-financial-assistant\models\local\regression\random_forest_model.pkl")

print("Classification model loaded 🚀")
# Out:
# Classification model loaded 🚀

# %%
#import sys
#!{sys.executable} -m pip install scikit-learn==1.2.2 --force-reinstall --no-cache-dir
